# %% [markdown]
# ## **Exercise 1.02 - Guided Exercise**
# ### Performing Structure Investigation on the Dataset

# %% [markdown]
# ### Importing Libraries
# Import the visualization libraries alongwith the other required ones.

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %matplotlib inline

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

import certifi
from sklearn.datasets import fetch_openml

# %% [markdown]
# ### Loading the Data

# %%
df = pd.read_csv('https://raw.githubusercontent.com/fenago/datawrangling/main/miami-housing.csv')
df.sample(5)
df.head()

# %% [markdown]
# ## **Structure Investigation**
# Let's first look at the general structure of the dataset. Size of the daatset needs to be analyzed.
# Then count the number of datatyoes present in the data

# %%
# Show size of the dataset
df.shape

# %%
# Count how many times each data type is present in the dataset
pd.value_counts(df.dtypes)

# %% [markdown]
# ## Structure of numerical features
# Numerical features will be identified here:
# Compute the number of unique entries

# %%
# For each numerical feature compute number of unique entries
unique_values = df.select_dtypes(include='number').nunique().sort_values()
plt.figure(figsize=(15, 4))
sns.set_style('whitegrid')

# %%
g = sns.barplot(x=unique_values.index, y=unique_values, palette='inferno')
g.set_yscale("log")
g.set_xticklabels(g.get_xticklabels(), rotation=45, horizontalalignment='right')
g.set_title('Unique values per frequency')
plt.show()

# %% [markdown]
# ## Conclusion of structure investigation
# The type of features will be explored here:

# %%
df.info() 
df.describe()
